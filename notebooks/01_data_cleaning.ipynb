# %%
print("Hello NFL Analytics!")
# Out:
# Hello NFL Analytics!

# %%
import pandas as pd

df = pd.read_csv("../data/NFL Play by Play 2009-2016 (v3).csv")

# Peek at the data
print(df.shape)
print(df.columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("../data/NFL Play by Play 2009-2016 (v3).csv")
#       5 # Peek at the data
#       6 print(df.shape)
#
# ...

# %%
import pandas as pd

df = pd.read_csv("cristianbajo/data/nfl-team-efficiency/data/nflstats/NFL Play by Play 2009-2016 (v3).csv")

print(df.shape)
print(df.columns)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("cristianbajo/data/nfl-team-efficiency/data/nflstats/NFL Play by Play 2009-2016 (v3).csv")
#       5 print(df.shape)
#       6 print(df.columns)
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/Users/cristianbajo/nfl-team-efficiency/data/nflstats/NFL Play by Play 2009-2016 (v3).csv")

print(df.shape)
print(df.columns)
df.head()
# Out:
# /var/folders/37/m6sb8jt56ws8k01bbg1mq36m0000gn/T/ipykernel_97956/677335722.py:3: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/cristianbajo/nfl-team-efficiency/data/nflstats/NFL Play by Play 2009-2016 (v3).csv")
# (362447, 102)
# Index(['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder',
#        'TimeSecs', 'PlayTimeDiff', 'SideofField',
#        ...
#        'yacEPA', 'Home_WP_pre', 'Away_WP_pre', 'Home_WP_post', 'Away_WP_post',
#        'Win_Prob', 'WPA', 'airWPA', 'yacWPA', 'Season'],
#       dtype='object', length=102)
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# ...
